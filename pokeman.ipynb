# %%
import pandas as pd
df=pd.read_csv('Pokemon.csv')

# %%
df.shape
# Out:
# (800, 13)

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.head()
# Out:
#    #                   Name  Type1   Type2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#5•	List all the poisonos character in pokemon
df.loc[(df.Type2=='Poison')]
# Out:
#        #                   Name  Type1   Type2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 16    13                 Weedle    Bug  Poison    195   40      35       30
# 17    14                 Kakuna    Bug  Poison    205   45      25       50
# 18    15               Beedrill    Bug  Poison    395   65      90       40
# 19    15  BeedrillMega Beedrill    Bug  Poison    495   65     150       40
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# ...

# %%
#1List all the names in pokemon
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
#2•	2How many fire related animals are there in pokemon
df.Type1.value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ghost        32
# Dragon       32
# Ground       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type1, dtype: int64

# %% [markdown]
# #How many grass related animals are there in pokemon?

# %%
#3•	3How many grass related animals are there in pokemon?
df.Type1.value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ghost        32
# Dragon       32
# Ground       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type1, dtype: int64

# %%
#4.•	4What is the average HP of grass type animals?
df.groupby('Name')['HP'].median()
# Out:
# Name
# Abomasnow                   90
# AbomasnowMega Abomasnow     90
# Abra                        25
# Absol                       65
# AbsolMega Absol             65
#                           ...
# Zoroark                     60
# Zorua                       40
# Zubat                       40
# Zweilous                    72
# Zygarde50% Forme           108
# Name: HP, Length: 800, dtype: int64

# %%
#5•	5List all the poisonos character in pokemon
df.loc[(df.Type2=='Poison')]
# Out:
#        #                   Name  Type1   Type2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 16    13                 Weedle    Bug  Poison    195   40      35       30
# 17    14                 Kakuna    Bug  Poison    205   45      25       50
# 18    15               Beedrill    Bug  Poison    395   65      90       40
# 19    15  BeedrillMega Beedrill    Bug  Poison    495   65     150       40
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# ...

# %%
#6•	6Which characater has the maximum speed ?
df.groupby('Name')['Speed'].max()
# Out:
# Name
# Abomasnow                   60
# AbomasnowMega Abomasnow     30
# Abra                        90
# Absol                       75
# AbsolMega Absol            115
#                           ...
# Zoroark                    105
# Zorua                       65
# Zubat                       55
# Zweilous                    58
# Zygarde50% Forme            95
# Name: Speed, Length: 800, dtype: int64

# %%
#7•	List all the fairy character in pokemon
df.loc[(df.Type2=='Fairy')]
# Out:
#        #                     Name     Type1  Type2  Total   HP  Attack  \
# 44    39               Jigglypuff    Normal  Fairy    270  115      45
# 45    40               Wigglytuff    Normal  Fairy    435  140      70
# 131  122                 Mr. Mime   Psychic  Fairy    460   40      45
# 188  174                Igglybuff    Normal  Fairy    210   90      30
# 198  183                   Marill     Water  Fairy    250   70      20
# 199  184                Azumarill     Water  Fairy    420  100      50
# 303  280                    Ralts   Psychic  Fairy    198   28      25
# 304  281                   Kirlia   Psychic  Fairy    278   38      35
# 305  282                Gardevoir   Psychic  Fairy    518   68      65
# 306  282  GardevoirMega Gardevoir   Psychic  Fairy    618   68      85
# 322  298                  Azurill    Normal  Fairy    190   50      20
# 328  303                   Mawile     Steel  Fairy    380   50      85
# ...

# %%
#8•	8How many generation one characters are there in pokemon ?
df.loc[(df.Generation=='1')].count()
# Out:
# #             0
# Name          0
# Type1         0
# Type2         0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
#9•	List all the characters in pokemon which is both Poison and flying.
df.loc[(df.Type2==['Poison'], ['Flying'])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-ed0548d75582> in <module>
#       1 #9•     List all the characters in pokemon which is both Poison and flying.
# ----> 2 df.loc[(df.Type2==['Poison'], ['Flying'])]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
#      31     @unpack_zerodim_and_defer("__ne__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
# ...

# %%
#•	10List speed and HP of flying character in pokemon 
df.loc[(df.Type2=='Flying')]
# Out:
#        #                       Name     Type1   Type2  Total   HP  Attack  \
# 6      6                  Charizard      Fire  Flying    534   78      84
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 15    12                 Butterfree       Bug  Flying    395   60      45
# 20    16                     Pidgey    Normal  Flying    251   40      45
# 21    17                  Pidgeotto    Normal  Flying    349   63      60
# ..   ...                        ...       ...     ...    ...  ...     ...
# 730  662                Fletchinder      Fire  Flying    382   62      73
# 731  663                 Talonflame      Fire  Flying    499   78      81
# 734  666                   Vivillon       Bug  Flying    411   80      52
# 771  701                   Hawlucha  Fighting  Flying    500   78      92
# 793  717                    Yveltal      Dark  Flying    680  126     131
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
